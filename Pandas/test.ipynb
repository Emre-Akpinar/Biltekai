# %%
import pandas as pd

# %%
df = pd.read_csv(r'C:\Users\akpin\PycharmProjects\Pandas\Flavors.csv')
df
# Out:
#                    Flavor Base Flavor Liked  Flavor Rating  Texture Rating  \
# 0     Mint Chocolate Chip     Vanilla   Yes           10.0             8.0
# 1               Chocolate   Chocolate   Yes            8.8             7.6
# 2                 Vanilla     Vanilla    No            4.7             5.0
# 3            Cookie Dough     Vanilla   Yes            6.9             6.5
# 4              Rocky Road   Chocolate   Yes            8.2             7.0
# 5               Pistachio     Vanilla    No            2.3             3.4
# 6             Cake Batter     Vanilla   Yes            6.5             6.0
# 7              Neapolitan     Vanilla    No            3.8             5.0
# 8  Chocolte Fudge Brownie   Chocolate   Yes            8.2             7.1
#
#    Total Rating
# 0          18.0
# 1          16.6
# 2           9.7
# 3          13.4
# 4          15.2
# 5           5.7
# 6          12.5
# 7           8.8
# 8          15.3

# %%
df.set_index("Base Flavor",inplace=True)

# %%
df.sort_index(ascending=True)
# Out:
#                              Flavor Liked  Flavor Rating  Texture Rating  \
# Base Flavor
# Chocolate                 Chocolate   Yes            8.8             7.6
# Chocolate                Rocky Road   Yes            8.2             7.0
# Chocolate    Chocolte Fudge Brownie   Yes            8.2             7.1
# Vanilla         Mint Chocolate Chip   Yes           10.0             8.0
# Vanilla                     Vanilla    No            4.7             5.0
# Vanilla                Cookie Dough   Yes            6.9             6.5
# Vanilla                   Pistachio    No            2.3             3.4
# Vanilla                 Cake Batter   Yes            6.5             6.0
# Vanilla                  Neapolitan    No            3.8             5.0
#
#              Total Rating
# Base Flavor
# Chocolate            16.6
# Chocolate            15.2
# Chocolate            15.3
# Vanilla              18.0
# Vanilla               9.7
# Vanilla              13.4
# ...

# %%
df2 = pd.read_csv(r'C:\Users\akpin\PycharmProjects\Pandas\Ice Cream Ratings.csv')
df2.set_index("Date",inplace=True)
df2
# Out:
#           Flavor Rating  Texture Rating  Overall Rating
# Date
# 1/1/2022       0.223090        0.040220        0.600129
# 1/2/2022       0.635886        0.938476        0.106264
# 1/3/2022       0.442323        0.044154        0.598112
# 1/4/2022       0.389128        0.549676        0.489353
# 1/5/2022       0.386887        0.519439        0.988280
# 1/6/2022       0.877984        0.193588        0.832827
# 1/7/2022       0.140995        0.325110        0.105147

# %%
df2.plot(xlabel="Date",ylabel="Rating")
# Out:
# <Axes: xlabel='Date', ylabel='Rating'>
